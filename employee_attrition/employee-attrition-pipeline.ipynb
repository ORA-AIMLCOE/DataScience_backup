# %% [markdown]
# # Employee attrition sample using ML Pipelines

# %% [markdown]
# ### OCI Data Science - Useful Tips
# <details>
# <summary><font size="2">Check for Public Internet Access</font></summary>
#
# ```python
# import requests
# response = requests.get("https://oracle.com")
# assert response.status_code==200, "Internet connection failed"
# ```
# </details>
# <details>
# <summary><font size="2">Helpful Documentation </font></summary>
# <ul><li><a href="https://docs.cloud.oracle.com/en-us/iaas/data-science/using/data-science.htm">Data Science Service Documentation</a></li>
# <li><a href="https://docs.cloud.oracle.com/iaas/tools/ads-sdk/latest/index.html">ADS documentation</a></li>
# </ul>
# </details>
# <details>
# <summary><font size="2">Typical Cell Imports and Settings for ADS</font></summary>
#
# ```python
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#
# import warnings
# warnings.filterwarnings('ignore')
#
# import logging
# logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.ERROR)
#
# import ads
# from ads.dataset.factory import DatasetFactory
# from ads.automl.provider import OracleAutoMLProvider
# from ads.automl.driver import AutoML
# from ads.evaluations.evaluator import ADSEvaluator
# from ads.common.data import ADSData
# from ads.explanations.explainer import ADSExplainer
# from ads.explanations.mlx_global_explainer import MLXGlobalExplainer
# from ads.explanations.mlx_local_explainer import MLXLocalExplainer
# from ads.catalog.model import ModelCatalog
# from ads.common.model_artifact import ModelArtifact
# ```
# </details>
# <details>
# <summary><font size="2">Useful Environment Variables</font></summary>
#
# ```python
# import os
# print(os.environ["NB_SESSION_COMPARTMENT_OCID"])
# print(os.environ["PROJECT_OCID"])
# print(os.environ["USER_OCID"])
# print(os.environ["TENANCY_OCID"])
# print(os.environ["NB_REGION"])
# ```
# </details>

# %%
import oci
import ads
import os
from os import environ
from ads.catalog.project import ProjectCatalog

ads.set_auth(auth='resource_principal')

# %%
# make sure there is access to the project and compartment
config_1 = oci.config.from_file("config", "DEFAULT")
compartment_id = 'ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q'
pc = ProjectCatalog(compartment_id=compartment_id)
# pc.list_projects()

# %%
pc

# %% [markdown]
# Fill in your resources details:

# %%
project_id = 'ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqavly2t7bg75kg5vwfhbbrwueoaghqukysxloimy53zyxa'

# %%
log_group_id = "ocid1.loggroup.oc1.iad.amaaaaaazv3jruqadtnj7vcpme764ebg5w7bza4c2etpvtwqi2bbzd2hlnea"

# %%
data_location = "orcl_attrition.csv"  # use: 'oci://<bucket>@<workspace>/'

# %%
# create a data science client to communicate with the service
config = oci.config.from_file("config", "DEFAULT")
data_science_client = oci.data_science.DataScienceClient(config)

# %%
# list all pipelines in the project
res = data_science_client.list_pipelines(compartment_id=compartment_id)
print(res.data)
# Out:
# [{
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.saml2idp.oc1..aaaaaaaagfdxcwndgbraz2pbram2jyfowctsnjsyjfcqvjdfv27pcpl4q3za/arvind.ranganath.r@oracle.com",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/arvind.ranganath.r@oracle.com",
#       "CreatedOn": "2024-04-22T10:08:34.485Z"
#     }
#   },
#   "display_name": "AccountingCalendar2",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqapywdkqpgqjshtvteixtjzclvp6wjt22nt2dou55iykxa",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2024-04-22T10:08:34.951000+00:00",
#   "time_updated": "2024-04-22T10:10:20.591000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.saml2idp.oc1..aaaaaaaagfdxcwndgbraz2pbram2jyfowctsnjsyjfcqvjdfv27pcpl4q3za/jagadishkumar.ramamoorthy@oracle.com",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice

#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-06-01T09:01:09.478000+00:00",
#   "time_updated": "2023-06-01T09:01:22.144000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-23T17:22:20.162Z"
#     }
#   },
#   "display_name": "pipeline_sample_employee-attrition-7528",
#   "freeform_tags": {
#     "pipeline-sample": "employee-attrition-sample"
#   },
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqa7hjogzci2nfyhzzewmm7juto5yvd6y5x73wrwpgepwaa",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-04-23T17:22:20.966000+00:00",
#   "time_updated": "2023-04-23T17:22:29.809000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-23T17:14:22.309Z"
#     }
#   },
#   "display_name": "pipeline_sample_employee-attrition-7528",
#   "freeform_tags": {
#     "pipeline-sample": "employee-attrition-sample"
#   },
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqaug5acsidow7upn5ft2dvfcuqx63dmh3zkxydgoukxdfq",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-04-23T17:14:22.810000+00:00",
#   "time_updated": "2023-04-23T17:14:30.002000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-13T14:36:25.957Z"
#     }
#   },
#   "display_name": "Document_Store",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqalhxdno2sw5g7xkbyi4e3lc34hxk2k3ckaoor6p7nyg3a",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-04-13T14:36:26.855000+00:00",
#   "time_updated": "2023-04-13T14:36:31.139000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-13T10:42:55.776Z"
#     }
#   },
#   "display_name": "employee_attrition_pipeline_with_log_v3",
#   "freeform_tags": {
#     "pipeline-sample": "employee-attrition-sample"
#   },
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqabhhch7i6e3o3rqrph6rmzj5vxquhrzoowomo6jy4wiwq",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-04-13T10:42:56.398000+00:00",
#   "time_updated": "2023-04-13T10:42:57.927000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-13T10:41:27.470Z"
#     }
#   },
#   "display_name": "employee_attrition_pipeline_with_log_v3",
#   "freeform_tags": {
#     "pipeline-sample": "employee-attrition-sample"
#   },
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqadsaxyubmzaryrrqf722g7wdfrrynwj3byqhrw37lqkgq",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-04-13T10:41:28.570000+00:00",
#   "time_updated": "2023-04-13T10:41:35.561000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-13T10:40:50.618Z"
#     }
#   },
#   "display_name": "employee_attrition_pipeline_with_log_v3",
#   "freeform_tags": {
#     "pipeline-sample": "employee-attrition-sample"
#   },
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqahgpvbyer6djxtckfbfzqhmda5pq4auuolpb6rqhcv7jq",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-04-13T10:40:51.488000+00:00",
#   "time_updated": "2023-04-13T10:40:59.196000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-13T08:51:56.689Z"
#     }
#   },
#   "display_name": "employee_attrition_pipeline_with_log_v3",
#   "freeform_tags": {
#     "pipeline-sample": "employee-attrition-sample"
#   },
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqakjvmby4hcg3zpboaj4hapsm25py5bdxye7esdt2ls7gq",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-04-13T08:51:57.382000+00:00",
#   "time_updated": "2023-04-13T08:52:05.618000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-13T08:07:50.233Z"
#     }
#   },
#   "display_name": "employee_attrition_pipeline_with_log_v3",
#   "freeform_tags": {
#     "pipeline-sample": "employee-attrition-sample"
#   },
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqa6rz3zv64w3wvvwig5257ng3mtv7pfoswdpl3rtedxgkq",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-04-13T08:07:51.460000+00:00",
#   "time_updated": "2023-04-13T08:07:59.761000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-13T07:49:53.633Z"
#     }
#   },
#   "display_name": "employee_attrition_pipeline_with_log_v3",
#   "freeform_tags": {
#     "pipeline-sample": "employee-attrition-sample"
#   },
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqarfwpz6gtcbqvptstbkc7x4uynhhnf2vgdxryrxvpqmda",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-04-13T07:49:54.397000+00:00",
#   "time_updated": "2023-04-13T07:50:04.785000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-12T04:41:07.783Z"
#     }
#   },
#   "display_name": "employee_attrition_pipeline_with_log_v2",
#   "freeform_tags": {
#     "pipeline-sample": "employee-attrition-sample"
#   },
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqayfc62yxiqpokugmspspruesskoeomqp4ybjwvlwe2dpq",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-04-12T04:41:09.574000+00:00",
#   "time_updated": "2023-04-12T04:41:17.744000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-12T04:31:34.285Z"
#     }
#   },
#   "display_name": "pipeline_with_logs",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqadgy5aezwopzc24ac5uqmcjbxqmmkbi7yxhza6zl4mxva",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-04-12T04:31:35.649000+00:00",
#   "time_updated": "2023-04-12T04:31:39.562000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-12T04:30:30.564Z"
#     }
#   },
#   "display_name": "ads_pipeline_sample_1011",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqaj6xuibrrugogfep7euxfoasp276zkvnw5dilbgmj3vlq",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-04-12T04:30:31.370000+00:00",
#   "time_updated": "2023-04-12T04:30:36.074000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaakvbukqqf2vriwzribcx3vjqjuwqww7r2sisb5pr233pw2yfnuuqa",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/anmol.gautam@oracle.com",
#       "CreatedOn": "2023-04-12T04:21:44.358Z"
#     }
#   },
#   "display_name": "ads_pipeline_sample_1011",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jru

#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqalag6zhwfqj55qcbm4ch2jd5znf5fdod2657v223bknna",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-03-17T14:11:29.022000+00:00",
#   "time_updated": "2023-03-17T14:11:34.300000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaagddwau6gvag3osijzo5h26o6dsuwv5m7aynyteqy45vqj5av6zyq",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/disha.poojari@oracle.com",
#       "CreatedOn": "2023-03-17T08:29:24.835Z"
#     }
#   },
#   "display_name": "soiled_image_processing_-6293",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqal4ft7brp7hyxtybroqaumqpjnhnvxfoabub2tmja3jsq",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-03-17T08:29:25.380000+00:00",
#   "time_updated": "2023-03-17T08:29:31.728000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaagddwau6gvag3osijzo5h26o6dsuwv5m7aynyteqy45vqj5av6zyq",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/disha.poojari@oracle.com",
#       "CreatedOn": "2023-03-17T08:12:15.492Z"
#     }
#   },
#   "display_name": "soiled_image_processing_-3896",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqay5kr3wju6ftctj3zbr6mr2jxhsynr5wu7obk7q6zx72q",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-03-17T08:12:15.900000+00:00",
#   "time_updated": "2023-03-17T08:12:23.049000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaagddwau6gvag3osijzo5h26o6dsuwv5m7aynyteqy45vqj5av6zyq",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/disha.poojari@oracle.com",
#       "CreatedOn": "2023-03-17T08:08:59.513Z"
#     }
#   },
#   "display_name": "soiled_image_processing_-8795",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqagaeq4eh7k73dk5xpsovlawne5ylvpik3bejywafo5oua",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-03-17T08:09:00.444000+00:00",
#   "time_updated": "2023-03-17T08:09:05.991000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaagddwau6gvag3osijzo5h26o6dsuwv5m7aynyteqy45vqj5av6zyq",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/disha.poojari@oracle.com",
#       "CreatedOn": "2023-03-17T07:52:55.148Z"
#     }
#   },
#   "display_name": "soiled_image_processing_-5964",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqamofjnq7y6cfild3clss77qdkzwq3fa535iblgwi2dbfa",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-03-17T07:52:55.715000+00:00",
#   "time_updated": "2023-03-17T07:53:00.681000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaagddwau6gvag3osijzo5h26o6dsuwv5m7aynyteqy45vqj5av6zyq",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/disha.poojari@oracle.com",
#       "CreatedOn": "2023-03-17T07:27:24.903Z"
#     }
#   },
#   "display_name": "soiled_image_processing_-5964",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqa6v2lw7gbiqoumqozai7woo3r2hkcd5ogatwnykpgcncq",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-03-17T07:27:25.287000+00:00",
#   "time_updated": "2023-03-17T07:27:30.844000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaagddwau6gvag3osijzo5h26o6dsuwv5m7aynyteqy45vqj5av6zyq",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/disha.poojari@oracle.com",
#       "CreatedOn": "2023-03-17T06:56:54.711Z"
#     }
#   },
#   "display_name": "soiled_image_processing_-6656",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqanqtgluwgwufoqdicjspyi6w33cukis2o5npqkt6ftuoa",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-03-17T06:56:55.144000+00:00",
#   "time_updated": "2023-03-17T06:57:00.217000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaagddwau6gvag3osijzo5h26o6dsuwv5m7aynyteqy45vqj5av6zyq",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/disha.poojari@oracle.com",
#       "CreatedOn": "2023-03-17T06:40:24.928Z"
#     }
#   },
#   "display_name": "soiled_image_processing_-5107",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqaxq7q5qgbdv262p4eekg2mbnmwkynbjkyy5ezsnwsafza",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-03-17T06:40:25.369000+00:00",
#   "time_updated": "2023-03-17T06:40:31.033000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaagddwau6gvag3osijzo5h26o6dsuwv5m7aynyteqy45vqj5av6zyq",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/disha.poojari@oracle.com",
#       "CreatedOn": "2023-03-16T04:54:00.266Z"
#     }
#   },
#   "display_name": "ads_pipeline_sample_-4696",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqaasgchf6lb3gxqjolcofyhjyz5mj6l5ncjun7uto5vkxq",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-03-16T04:54:02.490000+00:00",
#   "time_updated": "2023-03-16T04:54:10.202000+00:00"
# }, {
#   "compartment_id": "ocid1.compartment.oc1..aaaaaaaaretksgipt3jgwfpzgh4ijyw54uynyfviaxs5li4wtl744fj4fi3q",
#   "created_by": "ocid1.user.oc1..aaaaaaaagddwau6gvag3osijzo5h26o6dsuwv5m7aynyteqy45vqj5av6zyq",
#   "defined_tags": {
#     "Oracle-Tags": {
#       "CreatedBy": "oracleidentitycloudservice/disha.poojari@oracle.com",
#       "CreatedOn": "2023-03-16T04:35:11.954Z"
#     }
#   },
#   "display_name": "ads_pipeline_sample_-8020",
#   "freeform_tags": {},
#   "id": "ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqadm25xv7bun747kos436gmcxm7mii3scbfc4t2fvsku6q",
#   "lifecycle_state": "ACTIVE",
#   "project_id": "ocid1.datascienceproject.oc1.iad.amaaaaaazv3jruqax6p5pprd54qnyffrelimbt7zpjnt3iqbovh4xb5mqbea",
#   "system_tags": {},
#   "time_created": "2023-03-16T04:35:12.651000+00:00",
#   "time_updated": "2023-03-16T04:35:16.920000+00:00"
# }]

# %%
from random import randrange
pipeline_name = f"pipeline_sample_employee-attrition-{randrange(1000,9999)}"

# %%
# create a new pipeline (service conda pack)
pipeline_payload = {
    "projectId": project_id,
    "compartmentId": compartment_id,
    "displayName": pipeline_name,
    "infrastructureConfigurationDetails": {
        "shapeName": "VM.Standard2.4",
        "blockStorageSizeInGBs": "50"
    },
    "logConfigurationDetails": {
        "enableLogging": True,
        "logGroupId": log_group_id,
        "enableAutoLogCreation": True   # log will be automatically created
    },
    "configurationDetails": {
        "type": "DEFAULT",
        "maximumRuntimeInMinutes": 60,
        "environmentVariables": {
            "CONDA_ENV_TYPE": "service",
            "CONDA_ENV_SLUG": "pypgx2340_p38_cpu_v1"
        }
    },
    "stepDetails": [
        {
            "stepName": "data_processing",
            "description": "Import data, feature engineering, train-test split",
            "stepType": "CUSTOM_SCRIPT",
            "stepInfrastructureConfigurationDetails": {
                "shapeName": "VM.Standard2.4",
                "blockStorageSizeInGBs": "50"
            },
            "stepConfigurationDetails": {
                "type": "DEFAULT",
                "maximumRuntimeInMinutes": 30,
                "environmentVariables": {
                    "PIPELINE_STEP_RUN_ENTRYPOINT": "employee-attr-dataproc.py",
                    "CONDA_ENV_TYPE": "service",
                    "CONDA_ENV_SLUG": "pypgx2340_p38_cpu_v1",
                    "DATA_LOCATION": data_location
                }
            }
        },
        {
            "stepName": "train_logistic_regression",
            "description": "Train a Logistic Regression model and save to the model catalog with its AUC score",
            "stepType": "CUSTOM_SCRIPT",
            "stepInfrastructureConfigurationDetails": {
                "shapeName": "VM.Standard2.4",
                "blockStorageSizeInGBs": "50"
            },
            "stepConfigurationDetails": {
                "type": "DEFAULT",
                "maximumRuntimeInMinutes": 120,
                "environmentVariables": {
                    "PIPELINE_STEP_RUN_ENTRYPOINT": "employee-attr-train-lr.py",
                    "CONDA_ENV_TYPE": "service",
                    "CONDA_ENV_SLUG": "pypgx2340_p38_cpu_v1",
                    "DATA_LOCATION": data_location
                }
            },
            "dependsOn": ["data_processing"]
        },
        {
            "stepName": "train_random_forest",
            "description": "Train a Random Forest model and save to the model catalog with its AUC score",
            "stepType": "CUSTOM_SCRIPT",
            "stepInfrastructureConfigurationDetails": {
                "shapeName": "VM.Standard2.4",
                "blockStorageSizeInGBs": "50"
            },
            "stepConfigurationDetails": {
                "type": "DEFAULT",
                "maximumRuntimeInMinutes": 120,
                "environmentVariables": {
                    "PIPELINE_STEP_RUN_ENTRYPOINT": "employee-attr-train-rf.py",
                    "CONDA_ENV_TYPE": "service",
                    "CONDA_ENV_SLUG": "pypgx2340_p38_cpu_v1",
                    "DATA_LOCATION": data_location
                }
            },
            "dependsOn": ["data_processing"]
        },
        {
            "stepName": "train_xgboost",
            "description": "Train a model with XGBoost and save to the model catalog with its AUC score",
            "stepType": "CUSTOM_SCRIPT",
            "stepInfrastructureConfigurationDetails": {
                "shapeName": "VM.Standard2.4",
                "blockStorageSizeInGBs": "50"
            },
            "stepConfigurationDetails": {
                "type": "DEFAULT",
                "maximumRuntimeInMinutes": 120,
                "environmentVariables": {
                    "PIPELINE_STEP_RUN_ENTRYPOINT": "employee-attr-train-xgb.py",
                    "CONDA_ENV_TYPE": "service",
                    "CONDA_ENV_SLUG": "pypgx2340_p38_cpu_v1",
                    "DATA_LOCATION": data_location
                }
            },
            "dependsOn": ["data_processing"]
        },
        {
            "stepName": "evaluate_and_deploy",
            "description": "find the best model by their AUC score and deploy",
            "stepType": "CUSTOM_SCRIPT",
            "stepInfrastructureConfigurationDetails": {
                "shapeName": "VM.Standard2.4",
                "blockStorageSizeInGBs": "50"
            },
            "stepConfigurationDetails": {
                "type": "DEFAULT",
                "maximumRuntimeInMinutes": 30,
                "environmentVariables": {
                    "PIPELINE_STEP_RUN_ENTRYPOINT": "employee-attr-eval-deploy.py",
                    "CONDA_ENV_TYPE": "service",
                    "CONDA_ENV_SLUG": "pypgx2340_p38_cpu_v1",
                    "DATA_LOCATION": data_location
                }
            },
            "dependsOn": ["train_logistic_regression", "train_random_forest", "train_xgboost"]
        }
    ],
    "freeformTags": {
        "freeTags": "employee-attrition-sample"
    }
}
pipeline_res = data_science_client.create_pipeline(pipeline_payload)
pipeline_id = pipeline_res.data.id

# %%
print(pipeline_id)
# Out:
# ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqas4rcsfty4z2cugxjggvsniftonio4mlvo2tyubguf3oq

# %%
# the pipeline will be in CREATING state until all steps have their artifacts uploaded
print(pipeline_res.data.lifecycle_state)
# Out:
# CREATING

# %%
steps_names_and_artifacts = {"data_processing":"employee-attr-dataproc.zip",
                             "train_logistic_regression":"employee-attr-train-lr.zip",
                             "train_random_forest":"employee-attr-train-rf.zip",
                             "train_xgboost":"employee-attr-train-xgb.zip",
                             "evaluate_and_deploy":"employee-attr-eval-deploy.zip"}

# %%
# upload steps artifacts
for name in steps_names_and_artifacts:
    fl = open(steps_names_and_artifacts[name], "rb")
    ret = data_science_client.create_step_artifact(pipeline_id, name, fl, content_disposition=f"attachment; filename={steps_names_and_artifacts[name]}")
    print("OK" if ret.status==204 else ret.status)  # 204 is ok
# Out:
# OK
# OK
# OK
# OK
# OK

# %%
# pipeline should be in ACTIVE state now
res = data_science_client.get_pipeline(pipeline_id)
print(res.data.lifecycle_state)
# Out:
# ACTIVE

# %% [markdown]
# ## Run the pipeline

# %%
# set the configuration and the environment variables for the run
pipeline_run_name = f"pipeline-run-{randrange(1000,9999)}"

# %%
pipeline_run_payload = {
    "projectId": project_id,
    "displayName": pipeline_run_name,
    "pipelineId": pipeline_id,
    "compartmentId": compartment_id,
    "configurationOverrideDetails": {
        "type": "DEFAULT",
        "environmentVariables": {
            "DATA_LOCATION": data_location,
            "SKIP_MODEL_DEPLOY": "True"         # change to "False" to deploy the best model
        }
    }
}

# %%
pipelinerun_res = data_science_client.create_pipeline_run(pipeline_run_payload)

# %%
# check pipeline run status
run_status = data_science_client.get_pipeline_run(pipelinerun_res.data.id)
print(run_status.data.lifecycle_state)
# Out:
# ACCEPTED

# %% [markdown]
# ## Run the pipeline from the console UI

# %%
print("Ctrl-Click the hyperlink to open the pipeline run page in the OCI console UI")
print("https://cloud.oracle.com/data-science/pipelines/{}/pipeline-runs".format(pipeline_id))
# Out:
# Ctrl-Click the hyperlink to open the pipeline run page in the OCI console UI
# https://cloud.oracle.com/data-science/pipelines/ocid1.datasciencepipeline.oc1.iad.amaaaaaazv3jruqas4rcsfty4z2cugxjggvsniftonio4mlvo2tyubguf3oq/pipeline-runs

# %% [markdown]
# #### Don't forget to set the environment varaibles when running the pipeline: DATA_LOCATION
